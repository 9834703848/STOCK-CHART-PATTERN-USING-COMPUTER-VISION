# %% [markdown]
# <a href="https://colab.research.google.com/github/9834703848/STOCK-CHART-PATTERN-USING-COMPUTER-VISION/blob/master/Untitled39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install numpy==1.17.4

# %%
# %cd /content/drive/My Drive/tenserflow1
# Out:
# /content/drive/My Drive/tenserflow1

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# python-lxml is already the newest version (4.2.1-1ubuntu0.1).
# python-pil is already the newest version (5.1.0-1ubuntu0.3).
# python-tk is already the newest version (2.7.17-1~18.04).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
# %cd /content/drive/My Drive/tenserflow1/models/research
# Out:
# /content/drive/My Drive/tenserflow1/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
import os
os.environ['PYTHONPATH'] += ':/content/drive/My Drive/tenserflow1/models/research/:/content/drive/My Drive/tenserflow1/models/research/slim'

# %%
# !python setup.py build
# !python setup.py install
# Out:
# running build
# running build_py
# copying object_detection/protos/anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/argmax_matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/bipartite_matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/box_coder_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/box_predictor_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/graph_rewriter_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/calibration_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/grid_anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/eval_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/hyperparams_pb2.py -> build/lib/object_detection/protos
# ...

# %%
import time, psutil
Start = time.time()- psutil.boot_time()
Left= 12*3600 - Start
print('Time remaining for this session is: ', Left/3600, " hours")
# Out:
# Time remaining for this session is:  11.357000733216603  hours

# %%
# %cd /content/drive/My Drive/tenserflow1/models/research/object_detection/builders
# Out:
# /content/drive/My Drive/tenserflow1/models/research/object_detection/builders

# %%
# !python model_builder_test.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Running tests under Python 3.6.9: /usr/bin/python3
# [ RUN      ] ModelBuilderTest.test_create_experimental_model
# [       OK ] ModelBuilderTest.test_create_experimental_model
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# ...

# %%
# %cd /content/drive/My Drive/tenserflow1/models/research/object_detection
# Out:
# /content/drive/My Drive/tenserflow1/models/research/object_detection

# %%
# !mkdir -p images/train/ images/test/ training/
# !mkdir -p letterimages/train letterimages/test/

# %%
# !git clone https://github.com/NilsCode/FRCNN-ocr.git
# Out:
# Cloning into 'FRCNN-ocr'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 91 (delta 37), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (91/91), done.

# %%
# !mv FRCNN-ocr/Completedataset.py Completedataset.py
# !mv FRCNN-ocr/example.py example.py
# !mv FRCNN-ocr/labelmap.pbtxt training/

# %%
# !python example.py
# Out:
# Done Generating  0  images..
# Done Generating  10  images..
# Done Generating  20  images..
# Done Generating  30  images..
# Done Generating  40  images..
# Done Generating  50  images..
# Done Generating  60  images..
# Done Generating  70  images..
# Done Generating  80  images..
# Done Generating  90  images..
# Done Generating  100  images..
# Done Generating  110  images..
# Done Generating  120  images..
# Done Generating  130  images..
# Done Generating  140  images..
# Done Generating  150  images..
# Done Generating  160  images..
# Done Generating  170  images..
# Done Generating  180  images..
# Done Generating  190  images..
# Done Generating  0  images..
# Done Generating  10  images..
# Done Generating  20  images..
# Done Generating  30  images..
# Done Generating  40  images..
# Done Writing Train Lables to file..
# Done Writing Train Lables to file..
# Done writing  0  images to folder..
# Done writing  10  images to folder..
# Done writing  20  images to folder..
# ...

# %%
# %cd /content/drive/My Drive/tenserflow1/models/research/object_detection
# Out:
# /content/drive/My Drive/tenserflow1/models/research/object_detection

# %%
# !wget https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/samples/configs/faster_rcnn_inception_v2_coco.config
# Out:
# --2020-08-02 08:39:43--  https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/samples/configs/faster_rcnn_inception_v2_coco.config
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3738 (3.7K) [text/plain]
# Saving to: ‘faster_rcnn_inception_v2_coco.config’
#
# faster_rcnn_incepti 100%[===================>]   3.65K  --.-KB/s    in 0.001s
#
# 2020-08-02 08:39:43 (3.78 MB/s) - ‘faster_rcnn_inception_v2_coco.config’ saved [3738/3738]

# %%
# !python model_main.py --logtostderr --model_dir=shree/ --pipeline_config_path=training/faster_rcnn_inception_v2_coco.config
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From model_main.py:109: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/tenserflow1/models/research/object_detection/utils/config_util.py:102: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0802 08:49:01.056606 140268956759936 module_wrapper.py:139] From /content/drive/My Drive/tenserflow1/models/research/object_detection/utils/config_util.py:102: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/faster_rcnn_inception_v2_pets.config
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:56: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From train.py:56: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From train.py:185: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/absl/app.py:250: main (from __main__) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path training/faster_rcnn_inception_v2_pets.config --trained_checkpoint_prefix training/model.ckpt-46151 --output_directory shree
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From export_inference_graph.py:162: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0802 10:46:52.147131 139681805834112 module_wrapper.py:139] From export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
# Out:
# Missing output directives.
# 2020-08-02 08:03:34.274624: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "builders/model_builder_test.py", line 23, in <module>
#     from object_detection.builders import model_builder
# ModuleNotFoundError: No module named 'object_detection'

# %%
# Out:
# .object_detectionprotosanchor_generator.proto: No such file or directory

# %%
# Out:
# /bin/bash: slim: command not found
